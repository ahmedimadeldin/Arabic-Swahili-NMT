# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import pandas as pd
import sentencepiece as spm
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/txt_splitted_files.zip
# Out:
# Archive:  /content/drive/MyDrive/txt_splitted_files.zip
#   inflating: test.ar
#   inflating: test.sw
#   inflating: train.ar
#   inflating: train.sw

# %%
# !unzip /content/drive/MyDrive/DATA.zip
# Out:
# Archive:  /content/drive/MyDrive/DATA.zip
#   inflating: Arabic.txt
#   inflating: Swahili.txt

# %%
# !mkdir /content/bpe_dict_path
# Out:
# mkdir: cannot create directory ‘/content/bpe_dict_path’: File exists

# %%
# !mkdir /content/train/
# !mkdir /content/test/
# !mkdir /content/val/
# !mkdir /content/train_bpe/
# !mkdir /content/test_bpe/
# !mkdir /content/val_bpe/

# %%
#the entire files
All_ar_data = open("/content/Arabic.txt", "r").readlines()
All_sw_data = open("/content/Swahili.txt","r").readlines()
# the training files
train_ar_data = open("/content/train.ar", "r").readlines()
train_sw_data = open("/content/train.sw", "r").readlines()
# the test files
test_ar_data = open("/content/test.ar", "r").readlines()
test_sw_data = open("/content/test.sw", "r").readlines()


with open("/content/train/train.ar", "w") as fb:
    fb.writelines(train_ar_data[2000:])

with open("/content/train/train.sw", "w") as fb:
    fb.writelines(train_sw_data[2000:])

with open("/content/val/val.ar", "w") as fb:
    fb.writelines(train_ar_data[:2000])
with open("/content/val/val.sw", "w") as fb:
    fb.writelines(train_sw_data[:2000])

with open("/content/test/test.ar", "w") as fb:
    fb.writelines(test_ar_data)
with open("/content/test/test.sw", "w") as fb:
    fb.writelines(test_sw_data)

# %%
train_sw_data = open("/content/train/train.sw", "r").readlines()
test_sw_data = open("/content/test/test.sw", "r").readlines()
val_sw_data = open("/content/val/val.sw", "r").readlines()
print(len(train_sw_data) , len(test_sw_data) ,len(val_sw_data))
# Out:
# 27531 3281 2000

# %%
ar_source_file = "/content/Arabic.txt"
#english training file "all arabic text"
sw_source_file = "/content/Swahili.txt"
#swalihi_training file



dict_path = "/content/bpe_dict_path"
#dictionary "create directory and name it as you like"
ar_train_input = "/content/train/train.ar"
ar_train_bpe_output = "/content/train_bpe/train.bpe.ar"
sw_train_input = "/content/train/train.sw"
sw_train_bpe_output = "/content/train_bpe/train.bpe.sw"

ar_val_input = "/content/val/val.ar"
ar_val_bpe_output = "/content/val_bpe/val.bpe.ar"
sw_val_input = "/content/val/val.sw"
sw_val_bpe_output = "/content/val_bpe/val.bpe.sw"

ar_test_input = "/content/test/test.ar"
ar_test_bpe_output = "/content/test_bpe/test.bpe.ar"
sw_test_input = "/content/test/test.sw"
sw_test_bpe_output = "/content/test_bpe/test.bpe.sw"

vocab_size = 12000







#using entire text to find the dictonary for the BPE
def train_ar(vocab_size):
  model_prefix = dict_path+"/ar_" + "_vocab_" + str(vocab_size)
  spm.SentencePieceTrainer.train(input=ar_source_file
      , model_prefix=model_prefix
      , vocab_size=vocab_size
      , character_coverage = 0.9995
      , num_threads=60
      , model_type = "bpe"
      , train_extremely_large_corpus=True
  )
train_ar(vocab_size)

def train_sw(vocab_size):
  model_prefix = dict_path + "/sw_" + "_vocab_" + str(vocab_size)
  spm.SentencePieceTrainer.train(input=sw_source_file
      , model_prefix=model_prefix
      , vocab_size=vocab_size
      , character_coverage = 0.9995
      , num_threads=60
      ,model_type = "bpe"
      , train_extremely_large_corpus=True
  )
train_sw(vocab_size)

ar_tokenizer = spm.SentencePieceProcessor(model_file="/content/bpe_dict_path/ar__vocab_12000.model")
sw_tokenizer = spm.SentencePieceProcessor(model_file="/content/bpe_dict_path/sw__vocab_12000.model")




#from the above the BPE models are trained
####################################33


#lines uses the Arabic BPE model to tokenize the Arabic training data
with open(ar_train_input, "r", encoding="utf-8") as rf, open(ar_train_bpe_output, "w", encoding="utf-8") as wf:
    output_lines = []
    for line in rf.readlines():
        wf.write(' '.join(ar_tokenizer.encode(line, out_type=str)))
        # output_lines.append(tokenizer.encode(input = line, out_type = str))
        wf.write("\n")


with open(sw_train_input, "r", encoding="utf-8") as rf, open(sw_train_bpe_output, "w", encoding="utf-8") as wf:
    output_lines = []
    for line in rf.readlines():
        wf.write(' '.join(sw_tokenizer.encode(line, out_type=str)))
        # output_lines.append(tokenizer.encode(input = line, out_type = str))
        wf.write("\n")




with open(ar_test_input, "r", encoding="utf-8") as rf, open(ar_test_bpe_output, "w", encoding="utf-8") as wf:
    output_lines = []
    for line in rf.readlines():
        wf.write(' '.join(ar_tokenizer.encode(line, out_type=str)))
        # output_lines.append(tokenizer.encode(input = line, out_type = str))
        wf.write("\n")



with open(sw_test_input, "r", encoding="utf-8") as rf, open(sw_test_bpe_output, "w", encoding="utf-8") as wf:
    output_lines = []
    for line in rf.readlines():
        wf.write(' '.join(sw_tokenizer.encode(line, out_type=str)))
        # output_lines.append(tokenizer.encode(input = line, out_type = str))
        wf.write("\n")


with open(ar_val_input, "r", encoding="utf-8") as rf, open(ar_val_bpe_output, "w", encoding="utf-8") as wf:
    output_lines = []
    for line in rf.readlines():
        wf.write(' '.join(ar_tokenizer.encode(line, out_type=str)))
        # output_lines.append(tokenizer.encode(input = line, out_type = str))
        wf.write("\n")

    # wf.writelines(str(output_lines))



with open(sw_val_input, "r", encoding="utf-8") as rf, open(sw_val_bpe_output, "w", encoding="utf-8") as wf:
    output_lines = []
    for line in rf.readlines():
        wf.write(' '.join(sw_tokenizer.encode(line, out_type=str)))
        # output_lines.append(tokenizer.encode(input = line, out_type = str))
        wf.write("\n")

# %%
# !cut -f1 "/content/bpe_dict_path/ar__vocab_12000.vocab" | tail -n +4 | sed "s/$/ 100/g" > "/content/bpe_dict_path/fairseq.ar.vocab"
# !cut -f1 "/content/bpe_dict_path/sw__vocab_12000.vocab" | tail -n +4 | sed "s/$/ 100/g" > "/content/bpe_dict_path/fairseq.sw.vocab"

# %%
# !git clone https://github.com/pytorch/fairseq
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 34777, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 34777 (delta 0), reused 3 (delta 0), pack-reused 34769
# Receiving objects: 100% (34777/34777), 25.02 MiB | 27.02 MiB/s, done.
# Resolving deltas: 100% (25223/25223), done.

# %%
cd fairseq
# Out:
# /content/fairseq

# %%
# !pip install --editable ./
# Out:
# Obtaining file:///content/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (1.15.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (0.29.36)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 3.1 MB/s eta 0:00:00
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.21.3 in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (1.23.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (2023.6.3)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (4.66.1)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.2/286.2 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (2.0.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (23.1)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq==0.12.2) (4.7.1)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Collecting colorama (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (4.9.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->fairseq==0.12.2) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->fairseq==0.12.2) (16.0.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq==0.12.2) (2.21)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq==0.12.2) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq==0.12.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9396 sha256=f65a55fa63e55030a55ffad4cb933d8573dc849c6702bd0f859586dbb3504709
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l3tx7a6j/wheels/c6/d7/db/bc419b1daa8266aa8de2a7c4d29f62dbfa814e8701fe4695a2
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141209 sha256=f3b9a724c9b658c02e7315e2e58cfc0542a26ab4eb0c6af3796c873bd32450cb
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, colorama, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.8.1 colorama-0.4.6 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.7.0 sacrebleu-2.3.1

# %%
cd /content
# Out:
# /content

# %%
# !pip install fairseq
# Out:
# Requirement already satisfied: fairseq in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.15.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq) (0.29.36)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.0.7)
# Requirement already satisfied: omegaconf<2.1 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.0.6)
# Requirement already satisfied: numpy>=1.21.3 in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.23.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq) (2023.6.3)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.3.1)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq) (4.66.1)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.8.1)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.0.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fairseq) (23.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.10/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq) (6.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq) (4.7.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.7.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (4.9.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->fairseq) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->fairseq) (16.0.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq) (2.21)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->fairseq) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->fairseq) (1.3.0)

# %%
SOURCE_LANGUAGE="sw"
TARGET_LANGUAGE="ar"
TRAIN_PREF="/content/train_bpe/train.bpe"
VALID_PREF="/content/val_bpe/val.bpe"
TEST_PREF="/content/test_bpe/test.bpe"
DEST_DIR="/content/sw_ar.tokenized.sw-ar"
SRC_THRES=0
TGT_THRES=0
ar_DICT_PATH="/content/bpe_dict_path/fairseq.ar.vocab"
swahili_DICT_PATH="/content/bpe_dict_path/fairseq.sw.vocab"

# !fairseq-preprocess    --source-lang $SOURCE_LANGUAGE --target-lang $TARGET_LANGUAGE  \
   --srcdict "/content/bpe_dict_path/fairseq.sw.vocab"    --tgtdict "/content/bpe_dict_path/fairseq.ar.vocab"  --align-suffix align     --trainpref  $TRAIN_PREF        --validpref $VALID_PREF     --testpref $TEST_PREF   --destdir  $DEST_DIR     --thresholdsrc $SRC_THRES     --thresholdtgt $TGT_THRES
# Out:
# 2023-09-07 00:51:32.922608: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 00:51:34.234790: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:fairseq.tasks.text_to_speech:Please install tensorboardX: pip install tensorboardX
# INFO:fairseq_cli.preprocess:Namespace(no_progress_bar=False, log_interval=100, log_format=None, log_file=None, aim_repo=None, aim_run_hash=None, tensorboard_logdir=None, wandb_project=None, azureml_logging=False, seed=1, cpu=False, tpu=False, bf16=False, memory_efficient_bf16=False, fp16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, on_cpu_convert_precision=False, min_loss_scale=0.0001, threshold_loss_scale=None, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, quantization_config_path=None, profile=False, reset_logging=False, suppress_crashes=False, use_plasma_view=False, plasma_path='/tmp/plasma', criterion='cross_entropy', tokenizer=None, bpe=None, optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang='sw', target_lang='ar', trainpref='/content/train_bpe/train.bpe', validpref='/content/val_bpe/val.bpe', testpref='/content/test_bpe/test.bpe', align_suffix='align', destdir='/content/sw_ar.tokenized.sw-ar', thresholdtgt=0, thresholdsrc=0, tgtdict='/content/bpe_dict_path/fairseq.ar.vocab', srcdict='/content/bpe_dict_path/fairseq.sw.vocab', nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=False, only_source=False, padding_factor=8, workers=1, dict_only=False)
# INFO:fairseq_cli.preprocess:[sw] Dictionary: 12001 types
# INFO:fairseq_cli.preprocess:[sw] /content/train_bpe/train.bpe.sw: 27531 sents, 715812 tokens, 0.138% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[sw] Dictionary: 12001 types
# INFO:fairseq_cli.preprocess:[sw] /content/val_bpe/val.bpe.sw: 2000 sents, 52161 tokens, 0.144% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[sw] Dictionary: 12001 types
# INFO:fairseq_cli.preprocess:[sw] /content/test_bpe/test.bpe.sw: 3281 sents, 84840 tokens, 0.141% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[ar] Dictionary: 12001 types
# INFO:fairseq_cli.preprocess:[ar] /content/train_bpe/train.bpe.ar: 27531 sents, 670052 tokens, 0.0848% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[ar] Dictionary: 12001 types
# INFO:fairseq_cli.preprocess:[ar] /content/val_bpe/val.bpe.ar: 2000 sents, 49021 tokens, 0.0959% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[ar] Dictionary: 12001 types
# INFO:fairseq_cli.preprocess:[ar] /content/test_bpe/test.bpe.ar: 3281 sents, 78920 tokens, 0.0672% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:Wrote preprocessed data to /content/sw_ar.tokenized.sw-ar

# %%
# !pip install wandb
import wandb
wandb.login(key="apikey")
# Out:
# Collecting wandb
#   Downloading wandb-0.15.10-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.34-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.6/188.6 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.30.0-py2.py3-none-any.whl (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.8/218.8 kB 11.5 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=e08852fff30d9c47d4ada3f9bf7aeb06b638fcface4075e7bc04949a81fe9cac
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.34 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.30.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.15.10
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# %mkdir /content/drive/MyDrive/logs
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/logs’: File exists

# %%
DROPOUT=0.1
ATTENTION_DROPOUT=0
ACTIVATION_DROPOUT=0
EMBEDDING_SIZE=256
ENC_FFNN=1024
ENCODER_LAYERS=5
ENCODER_ATTENTION_HEADS=8
DECODER_LAYERS=5
DECODER_ATTENTION_HEADS=8
DEC_FFNN=1024
EPOCH=550
BATCH_SIZE=4096
ENCODER_LAYER_DROPOUT=0.1
DECODER_LAYER_DROPOUT=0.1
# SOURCE_LANGUAGE=swl
# TARGET_LANGUAGE=ar
LABEL_SMOOTHING=0.1
SAVE_DIR="/content/drive/MyDrive/sept3/checkpoints/"
LABEL_CROSS_ENTROPY="label_smoothed_cross_entropy"
WARMUP_UPDATES=4000
lEARNING_POLICY="inverse_sqrt"
WAND_PROJECT_NAME="LARGE_SCALE_AR_TO_SWAHILI_Translation"

# !fairseq-train "/content/sw_ar.tokenized.sw-ar" \
    --arch transformer \
    --dropout $DROPOUT \
    --attention-dropout 0     --encoder-embed-dim $EMBEDDING_SIZE \
    --encoder-ffn-embed-dim $ENC_FFNN  \
    --encoder-layers $ENCODER_LAYERS  \
    --encoder-attention-heads $ENCODER_ATTENTION_HEADS \
    --encoder-learned-pos  \
    --decoder-embed-dim $EMBEDDING_SIZE \
    --decoder-ffn-embed-dim $DEC_FFNN  \
    --decoder-layers $DECODER_LAYERS \
    --decoder-attention-heads $DECODER_ATTENTION_HEADS \
    --decoder-learned-pos   \
    --max-epoch $EPOCH  \
    --optimizer adam \
    --lr 5e-4 \
    --max-tokens $BATCH_SIZE \
    --seed 1     --encoder-layerdrop $ENCODER_LAYER_DROPOUT     --decoder-layerdrop $DECODER_LAYER_DROPOUT \
    --criterion $LABEL_CROSS_ENTROPY     --warmup-updates $WARMUP_UPDATES \
    --source-lang sw    --label-smoothing $LABEL_SMOOTHING \
    --lr-scheduler $lEARNING_POLICY   --save-dir $SAVE_DIR \
    --find-unused-parameters  \
    --target-lang ar \
    --activation-dropout $ACTIVATION_DROPOUT  \
    --ddp-backend=no_c10d \
    --no-epoch-checkpoints --wandb-project $WAND_PROJECT_NAME \
    --log-format=json --log-interval=10 2>&1    |  tee  "/content/drive/MyDrive/logs/training_log.log"
# Out:
# 2023-09-03 23:41:57 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2023-09-03 23:42:00 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 10, 'log_format': 'json', 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': 'LARGE_SCALE_AR_TO_SWAHILI_Translation', 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'no_c10d', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': True, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4096, 'batch_size': None, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4096, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 550, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': '/content/drive/MyDrive/sept3/checkpoints/', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': True, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'c ...
# 2023-09-03 23:42:00 | INFO | fairseq.tasks.translation | [sw] dictionary: 12001 types
# 2023-09-03 23:42:00 | INFO | fairseq.tasks.translation | [ar] dictionary: 12001 types
# 2023-09-03 23:42:01 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(12001, 256, padding_idx=1)
#     (embed_positions): LearnedPositionalEmbedding(1026, 256, padding_idx=1)
#     (layers): LayerDropModuleList(
#       (0): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(12001, 256, padding_idx=1)
#     (embed_positions): LearnedPositionalEmbedding(1026, 256, padding_idx=1)
#     (layers): LayerDropModuleList(
#       (0): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=256, out_features=12001, bias=False)
#   )
# )
# 2023-09-03 23:42:01 | INFO | fairseq_cli.train | task: TranslationTask
# 2023-09-03 23:42:01 | INFO | fairseq_cli.train | model: TransformerModel
# 2023-09-03 23:42:01 | INFO | fairseq_cli.train | criterion: LabelSmoothedCrossEntropyCriterion
# 2023-09-03 23:42:01 | INFO | fairseq_cli.train | num. shared model params: 18,958,080 (num. trained: 18,958,080)
# 2023-09-03 23:42:01 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2023-09-03 23:42:01 | INFO | fairseq.data.data_utils | loaded 2,000 examples from: /content/sw_ar.tokenized.sw-ar/valid.sw-ar.sw
# 2023-09-03 23:42:01 | INFO | fairseq.data.data_utils | loaded 2,000 examples from: /content/sw_ar.tokenized.sw-ar/valid.sw-ar.ar
# 2023-09-03 23:42:01 | INFO | fairseq.tasks.translation | /content/sw_ar.tokenized.sw-ar valid sw-ar 2000 examples
# 2023-09-03 23:42:03 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2023-09-03 23:42:03 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 14.748 GB ; name = Tesla T4
# 2023-09-03 23:42:03 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2023-09-03 23:42:03 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2023-09-03 23:42:03 | INFO | fairseq_cli.train | max tokens per device = 4096 and max sentences per device = None
# 2023-09-03 23:42:03 | INFO | fairseq.trainer | Preparing to load checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:42:04 | INFO | fairseq.trainer | NOTE: your device may support faster training with --fp16 or --amp
# 2023-09-03 23:42:04 | INFO | fairseq.trainer | Loaded checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt (epoch 421 @ 91140 updates)
# 2023-09-03 23:42:04 | INFO | fairseq.trainer | loading train data for epoch 421
# 2023-09-03 23:42:04 | INFO | fairseq.data.data_utils | loaded 27,531 examples from: /content/sw_ar.tokenized.sw-ar/train.sw-ar.sw
# 2023-09-03 23:42:04 | INFO | fairseq.data.data_utils | loaded 27,531 examples from: /content/sw_ar.tokenized.sw-ar/train.sw-ar.ar
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.translation | /content/sw_ar.tokenized.sw-ar train sw-ar 27531 examples
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | reuse_dataloader = True
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | rebuild_batches = False
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | creating new batches for epoch 421
# 2023-09-03 23:42:04 | INFO | fairseq_cli.train | begin dry-run validation on "valid" subset
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | reuse_dataloader = True
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | rebuild_batches = False
# 2023-09-03 23:42:04 | INFO | fairseq.tasks.fairseq_task | creating new batches for epoch 1
# 2023-09-03 23:42:05 | INFO | fairseq.data.iterators | grouped total_num_itrs = 217
# wandb: Currently logged in as: arabic-swahilimt (arabic-swahili). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /content/wandb/run-20230903_234205-u97p08ck
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run hearty-water-50
# wandb: ⭐️ View project at https://wandb.ai/arabic-swahili/LARGE_SCALE_AR_TO_SWAHILI_Translation
# wandb: 🚀 View run at https://wandb.ai/arabic-swahili/LARGE_SCALE_AR_TO_SWAHILI_Translation/runs/u97p08ck
# 2023-09-03 23:42:06 | INFO | fairseq.trainer | begin training epoch 421
# 2023-09-03 23:42:06 | INFO | fairseq_cli.train | Start iterating over samples
# /content/fairseq/fairseq/utils.py:374: UserWarning: amp_C fused kernels unavailable, disabling multi_tensor_l2norm; you may get better performance by installing NVIDIA's apex library
#   warnings.warn(
# 2023-09-03 23:42:08 | INFO | train_inner | {"epoch": 421, "update": 420.046, "loss": "2.181", "nll_loss": "0.304", "ppl": "1.23", "wps": "22824.6", "ups": "7.76", "wpb": "2814.6", "bsz": "163.2", "num_updates": "91150", "lr": "0.000104742", "gnorm": "0.556", "train_wall": "2", "gb_free": "13.4", "wall": "5"}
# 2023-09-03 23:42:09 | INFO | train_inner | {"epoch": 421, "update": 420.092, "loss": "2.155", "nll_loss": "0.292", "ppl": "1.22", "wps": "24848.5", "ups": "7.93", "wpb": "3132.1", "bsz": "132", "num_updates": "91160", "lr": "0.000104736", "gnorm": "0.511", "train_wall": "1", "gb_free": "13.4", "wall": "6"}
# 2023-09-03 23:42:11 | INFO | train_inner | {"epoch": 421, "update": 420.138, "loss": "2.213", "nll_loss": "0.338", "ppl": "1.26", "wps": "24909.4", "ups": "8.11", "wpb": "3071.4", "bsz": "92", "num_updates": "91170", "lr": "0.000104731", "gnorm": "0.563", "train_wall": "1", "gb_free": "13.4", "wall": "7"}
# 2023-09-03 23:42:12 | INFO | train_inner | {"epoch": 421, "update": 420.184, "loss": "2.299", "nll_loss": "0.431", "ppl": "1.35", "wps": "27674.5", "ups": "8.44", "wpb": "3277.4", "bsz": "156.8", "num_updates": "91180", "lr": "0.000104725", "gnorm": "0.65", "train_wall": "1", "gb_free": "13.5", "wall": "9"}
# 2023-09-03 23:42:13 | INFO | train_inner | {"epoch": 421, "update": 420.23, "loss": "2.25", "nll_loss": "0.381", "ppl": "1.3", "wps": "26046.8", "ups": "8.22", "wpb": "3170.4", "bsz": "110.4", "num_updates": "91190", "lr": "0.000104719", "gnorm": "0.539", "train_wall": "1", "gb_free": "13.4", "wall": "10"}
# 2023-09-03 23:42:14 | INFO | train_inner | {"epoch": 421, "update": 420.276, "loss": "2.275", "nll_loss": "0.412", "ppl": "1.33", "wps": "27370.5", "ups": "8.6", "wpb": "3181.7", "bsz": "117.6", "num_updates": "91200", "lr": "0.000104713", "gnorm": "0.676", "train_wall": "1", "gb_free": "13.5", "wall": "11"}
# 2023-09-03 23:42:15 | INFO | train_inner | {"epoch": 421, "update": 420.323, "loss": "2.226", "nll_loss": "0.336", "ppl": "1.26", "wps": "23851.6", "ups": "8.66", "wpb": "2753.1", "bsz": "138.4", "num_updates": "91210", "lr": "0.000104708", "gnorm": "0.597", "train_wall": "1", "gb_free": "13.4", "wall": "12"}
# 2023-09-03 23:42:17 | INFO | train_inner | {"epoch": 421, "update": 420.369, "loss": "2.234", "nll_loss": "0.364", "ppl": "1.29", "wps": "22226.3", "ups": "7.91", "wpb": "2810.8", "bsz": "142.4", "num_updates": "91220", "lr": "0.000104702", "gnorm": "0.583", "train_wall": "1", "gb_free": "13.5", "wall": "13"}
# 2023-09-03 23:42:18 | INFO | train_inner | {"epoch": 421, "update": 420.415, "loss": "2.228", "nll_loss": "0.366", "ppl": "1.29", "wps": "20539", "ups": "7.01", "wpb": "2928.6", "bsz": "98.4", "num_updates": "91230", "lr": "0.000104696", "gnorm": "0.527", "train_wall": "1", "gb_free": "14.1", "wall": "15"}
# 2023-09-03 23:42:19 | INFO | train_inner | {"epoch": 421, "update": 420.461, "loss": "2.558", "nll_loss": "0.705", "ppl": "1.63", "wps": "23902.4", "ups": "7.25", "wpb": "3297.4", "bsz": "119.2", "num_updates": "91240", "lr": "0.000104691", "gnorm": "0.761", "train_wall": "1", "gb_free": "13.5", "wall": "16"}
# 2023-09-03 23:42:21 | INFO | train_inner | {"epoch": 421, "update": 420.507, "loss": "2.251", "nll_loss": "0.387", "ppl": "1.31", "wps": "20440.4", "ups": "6.34", "wpb": "3224.7", "bsz": "138.4", "num_updates": "91250", "lr": "0.000104685", "gnorm": "0.563", "train_wall": "1", "gb_free": "13.4", "wall": "18"}
# 2023-09-03 23:42:23 | INFO | train_inner | {"epoch": 421, "update": 420.553, "loss": "2.194", "nll_loss": "0.315", "ppl": "1.24", "wps": "20571.7", "ups": "6.61", "wpb": "3111.3", "bsz": "124.8", "num_updates": "91260", "lr": "0.000104679", "gnorm": "0.487", "train_wall": "1", "gb_free": "13.5", "wall": "19"}
# 2023-09-03 23:42:24 | INFO | train_inner | {"epoch": 421, "update": 420.599, "loss": "2.354", "nll_loss": "0.486", "ppl": "1.4", "wps": "21619.5", "ups": "6.65", "wpb": "3253.2", "bsz": "103.2", "num_updates": "91270", "lr": "0.000104673", "gnorm": "0.615", "train_wall": "1", "gb_free": "13.4", "wall": "21"}
# 2023-09-03 23:42:25 | INFO | train_inner | {"epoch": 421, "update": 420.645, "loss": "2.164", "nll_loss": "0.305", "ppl": "1.24", "wps": "22760.4", "ups": "7.63", "wpb": "2981.7", "bsz": "128", "num_updates": "91280", "lr": "0.000104668", "gnorm": "0.506", "train_wall": "1", "gb_free": "13.4", "wall": "22"}
# 2023-09-03 23:42:27 | INFO | train_inner | {"epoch": 421, "update": 420.691, "loss": "2.166", "nll_loss": "0.299", "ppl": "1.23", "wps": "23425.4", "ups": "7.84", "wpb": "2988.3", "bsz": "147.2", "num_updates": "91290", "lr": "0.000104662", "gnorm": "0.52", "train_wall": "1", "gb_free": "13.6", "wall": "23"}
# 2023-09-03 23:42:28 | INFO | train_inner | {"epoch": 421, "update": 420.737, "loss": "2.219", "nll_loss": "0.347", "ppl": "1.27", "wps": "24911.3", "ups": "7.9", "wpb": "3154.5", "bsz": "101.6", "num_updates": "91300", "lr": "0.000104656", "gnorm": "0.538", "train_wall": "1", "gb_free": "13.4", "wall": "25"}
# 2023-09-03 23:42:29 | INFO | train_inner | {"epoch": 421, "update": 420.783, "loss": "2.298", "nll_loss": "0.406", "ppl": "1.33", "wps": "25799.1", "ups": "8.44", "wpb": "3058", "bsz": "147.2", "num_updates": "91310", "lr": "0.00010465", "gnorm": "0.623", "train_wall": "1", "gb_free": "13.5", "wall": "26"}
# 2023-09-03 23:42:30 | INFO | train_inner | {"epoch": 421, "update": 420.829, "loss": "2.231", "nll_loss": "0.367", "ppl": "1.29", "wps": "24269.6", "ups": "8.17", "wpb": "2969.3", "bsz": "151.2", "num_updates": "91320", "lr": "0.000104645", "gnorm": "0.696", "train_wall": "1", "gb_free": "13.4", "wall": "27"}
# 2023-09-03 23:42:32 | INFO | train_inner | {"epoch": 421, "update": 420.876, "loss": "2.284", "nll_loss": "0.408", "ppl": "1.33", "wps": "26574.7", "ups": "8.15", "wpb": "3259.7", "bsz": "112.8", "num_updates": "91330", "lr": "0.000104639", "gnorm": "0.64", "train_wall": "1", "gb_free": "13.5", "wall": "28"}
# 2023-09-03 23:42:33 | INFO | train_inner | {"epoch": 421, "update": 420.922, "loss": "2.166", "nll_loss": "0.302", "ppl": "1.23", "wps": "23311.9", "ups": "7.81", "wpb": "2984.2", "bsz": "124.8", "num_updates": "91340", "lr": "0.000104633", "gnorm": "0.522", "train_wall": "1", "gb_free": "13.4", "wall": "30"}
# 2023-09-03 23:42:34 | INFO | train_inner | {"epoch": 421, "update": 420.968, "loss": "2.208", "nll_loss": "0.332", "ppl": "1.26", "wps": "26119.9", "ups": "8.08", "wpb": "3232.8", "bsz": "117.6", "num_updates": "91350", "lr": "0.000104627", "gnorm": "0.578", "train_wall": "1", "gb_free": "13.3", "wall": "31"}
# 2023-09-03 23:42:35 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-09-03 23:42:35 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:42:36 | INFO | valid | {"epoch": 421, "valid_loss": "9.504", "valid_nll_loss": "8.659", "valid_ppl": "404.34", "valid_wps": "48083", "valid_wpb": "2334.3", "valid_bsz": "95.2", "valid_num_updates": "91357", "valid_best_loss": "8.369"}
# 2023-09-03 23:42:36 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 421 @ 91357 updates
# 2023-09-03 23:42:36 | INFO | fairseq.trainer | Saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:42:38 | INFO | fairseq.trainer | Finished saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:42:38 | INFO | fairseq.checkpoint_utils | Saved checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt (epoch 421 @ 91357 updates, score 9.504) (writing took 1.4216579159999583 seconds)
# 2023-09-03 23:42:38 | INFO | fairseq_cli.train | end of epoch 421 (average epoch stats below)
# 2023-09-03 23:42:38 | INFO | train | {"epoch": 421, "train_loss": "2.246", "train_nll_loss": "0.376", "train_ppl": "1.3", "train_wps": "21831.1", "train_ups": "7.06", "train_wpb": "3086.4", "train_bsz": "126.9", "train_num_updates": "91357", "train_lr": "0.000104623", "train_gnorm": "0.581", "train_train_wall": "28", "train_gb_free": "13.5", "train_wall": "34"}
# 2023-09-03 23:42:38 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:42:38 | INFO | fairseq.data.iterators | grouped total_num_itrs = 217
# 2023-09-03 23:42:38 | INFO | fairseq.trainer | begin training epoch 422
# 2023-09-03 23:42:38 | INFO | fairseq_cli.train | Start iterating over samples
# 2023-09-03 23:42:38 | INFO | train_inner | {"epoch": 422, "update": 421.014, "loss": "2.177", "nll_loss": "0.301", "ppl": "1.23", "wps": "7904.1", "ups": "2.44", "wpb": "3240.4", "bsz": "126.4", "num_updates": "91360", "lr": "0.000104622", "gnorm": "0.492", "train_wall": "1", "gb_free": "13.6", "wall": "35"}
# 2023-09-03 23:42:40 | INFO | train_inner | {"epoch": 422, "update": 421.06, "loss": "2.239", "nll_loss": "0.368", "ppl": "1.29", "wps": "20434.4", "ups": "6.57", "wpb": "3109.7", "bsz": "119.2", "num_updates": "91370", "lr": "0.000104616", "gnorm": "0.589", "train_wall": "1", "gb_free": "13.5", "wall": "37"}
# 2023-09-03 23:42:41 | INFO | train_inner | {"epoch": 422, "update": 421.106, "loss": "2.348", "nll_loss": "0.499", "ppl": "1.41", "wps": "19936.4", "ups": "6.78", "wpb": "2942.5", "bsz": "156.8", "num_updates": "91380", "lr": "0.00010461", "gnorm": "0.693", "train_wall": "1", "gb_free": "13.4", "wall": "38"}
# 2023-09-03 23:42:43 | INFO | train_inner | {"epoch": 422, "update": 421.152, "loss": "2.228", "nll_loss": "0.356", "ppl": "1.28", "wps": "20227.9", "ups": "6.71", "wpb": "3013.4", "bsz": "124.8", "num_updates": "91390", "lr": "0.000104605", "gnorm": "0.578", "train_wall": "1", "gb_free": "13.5", "wall": "39"}
# 2023-09-03 23:42:44 | INFO | train_inner | {"epoch": 422, "update": 421.198, "loss": "2.328", "nll_loss": "0.457", "ppl": "1.37", "wps": "25753.3", "ups": "8.33", "wpb": "3092.8", "bsz": "108.8", "num_updates": "91400", "lr": "0.000104599", "gnorm": "0.683", "train_wall": "1", "gb_free": "13.5", "wall": "41"}
# 2023-09-03 23:42:45 | INFO | train_inner | {"epoch": 422, "update": 421.244, "loss": "2.164", "nll_loss": "0.293", "ppl": "1.22", "wps": "22632.2", "ups": "8.25", "wpb": "2744.2", "bsz": "126.4", "num_updates": "91410", "lr": "0.000104593", "gnorm": "0.523", "train_wall": "1", "gb_free": "13.4", "wall": "42"}
# 2023-09-03 23:42:46 | INFO | train_inner | {"epoch": 422, "update": 421.29, "loss": "2.183", "nll_loss": "0.332", "ppl": "1.26", "wps": "23548.5", "ups": "7.48", "wpb": "3147.5", "bsz": "110.4", "num_updates": "91420", "lr": "0.000104587", "gnorm": "0.513", "train_wall": "1", "gb_free": "13.3", "wall": "43"}
# 2023-09-03 23:42:48 | INFO | train_inner | {"epoch": 422, "update": 421.336, "loss": "2.177", "nll_loss": "0.305", "ppl": "1.24", "wps": "19423.1", "ups": "6.48", "wpb": "2995.2", "bsz": "96.8", "num_updates": "91430", "lr": "0.000104582", "gnorm": "0.506", "train_wall": "2", "gb_free": "13.4", "wall": "45"}
# 2023-09-03 23:42:49 | INFO | train_inner | {"epoch": 422, "update": 421.382, "loss": "2.166", "nll_loss": "0.302", "ppl": "1.23", "wps": "20645.6", "ups": "6.97", "wpb": "2963", "bsz": "104", "num_updates": "91440", "lr": "0.000104576", "gnorm": "0.498", "train_wall": "1", "gb_free": "13.3", "wall": "46"}
# 2023-09-03 23:42:51 | INFO | train_inner | {"epoch": 422, "update": 421.429, "loss": "2.304", "nll_loss": "0.425", "ppl": "1.34", "wps": "25495.2", "ups": "8.08", "wpb": "3154.8", "bsz": "123.2", "num_updates": "91450", "lr": "0.00010457", "gnorm": "0.653", "train_wall": "1", "gb_free": "13.4", "wall": "47"}
# 2023-09-03 23:42:52 | INFO | train_inner | {"epoch": 422, "update": 421.475, "loss": "2.275", "nll_loss": "0.397", "ppl": "1.32", "wps": "27288.6", "ups": "7.97", "wpb": "3424", "bsz": "119.2", "num_updates": "91460", "lr": "0.000104565", "gnorm": "0.617", "train_wall": "1", "gb_free": "13.5", "wall": "49"}
# 2023-09-03 23:42:53 | INFO | train_inner | {"epoch": 422, "update": 421.521, "loss": "2.241", "nll_loss": "0.373", "ppl": "1.3", "wps": "24037.8", "ups": "7.44", "wpb": "3230.1", "bsz": "153.6", "num_updates": "91470", "lr": "0.000104559", "gnorm": "0.552", "train_wall": "1", "gb_free": "13.5", "wall": "50"}
# 2023-09-03 23:42:55 | INFO | train_inner | {"epoch": 422, "update": 421.567, "loss": "2.336", "nll_loss": "0.45", "ppl": "1.37", "wps": "23604.8", "ups": "7.23", "wpb": "3264.7", "bsz": "120", "num_updates": "91480", "lr": "0.000104553", "gnorm": "0.677", "train_wall": "1", "gb_free": "13.4", "wall": "51"}
# 2023-09-03 23:42:56 | INFO | train_inner | {"epoch": 422, "update": 421.613, "loss": "2.168", "nll_loss": "0.298", "ppl": "1.23", "wps": "19142.4", "ups": "6.71", "wpb": "2852.8", "bsz": "111.2", "num_updates": "91490", "lr": "0.000104547", "gnorm": "0.551", "train_wall": "1", "gb_free": "13.4", "wall": "53"}
# 2023-09-03 23:42:58 | INFO | train_inner | {"epoch": 422, "update": 421.659, "loss": "2.198", "nll_loss": "0.327", "ppl": "1.25", "wps": "20675.1", "ups": "6.44", "wpb": "3211.7", "bsz": "140", "num_updates": "91500", "lr": "0.000104542", "gnorm": "0.528", "train_wall": "1", "gb_free": "13.4", "wall": "55"}
# 2023-09-03 23:42:59 | INFO | train_inner | {"epoch": 422, "update": 421.705, "loss": "2.182", "nll_loss": "0.306", "ppl": "1.24", "wps": "20062.4", "ups": "6.48", "wpb": "3097.7", "bsz": "143.2", "num_updates": "91510", "lr": "0.000104536", "gnorm": "0.497", "train_wall": "1", "gb_free": "13.3", "wall": "56"}
# 2023-09-03 23:43:01 | INFO | train_inner | {"epoch": 422, "update": 421.751, "loss": "2.251", "nll_loss": "0.382", "ppl": "1.3", "wps": "19474.2", "ups": "6.51", "wpb": "2989.2", "bsz": "108.8", "num_updates": "91520", "lr": "0.00010453", "gnorm": "0.555", "train_wall": "1", "gb_free": "13.5", "wall": "58"}
# 2023-09-03 23:43:02 | INFO | train_inner | {"epoch": 422, "update": 421.797, "loss": "2.214", "nll_loss": "0.34", "ppl": "1.27", "wps": "24316.2", "ups": "7.66", "wpb": "3175.6", "bsz": "132.8", "num_updates": "91530", "lr": "0.000104525", "gnorm": "0.55", "train_wall": "1", "gb_free": "13.4", "wall": "59"}
# 2023-09-03 23:43:03 | INFO | train_inner | {"epoch": 422, "update": 421.843, "loss": "2.225", "nll_loss": "0.349", "ppl": "1.27", "wps": "24671", "ups": "7.83", "wpb": "3152.3", "bsz": "150.4", "num_updates": "91540", "lr": "0.000104519", "gnorm": "0.561", "train_wall": "1", "gb_free": "13.5", "wall": "60"}
# 2023-09-03 23:43:05 | INFO | train_inner | {"epoch": 422, "update": 421.889, "loss": "2.262", "nll_loss": "0.389", "ppl": "1.31", "wps": "23246.3", "ups": "7.93", "wpb": "2932.7", "bsz": "145.6", "num_updates": "91550", "lr": "0.000104513", "gnorm": "0.585", "train_wall": "1", "gb_free": "13.5", "wall": "61"}
# 2023-09-03 23:43:06 | INFO | train_inner | {"epoch": 422, "update": 421.935, "loss": "2.268", "nll_loss": "0.391", "ppl": "1.31", "wps": "26127.3", "ups": "7.7", "wpb": "3393.5", "bsz": "124", "num_updates": "91560", "lr": "0.000104507", "gnorm": "0.578", "train_wall": "1", "gb_free": "13.4", "wall": "63"}
# 2023-09-03 23:43:07 | INFO | train_inner | {"epoch": 422, "update": 421.982, "loss": "2.349", "nll_loss": "0.479", "ppl": "1.39", "wps": "24516.2", "ups": "8.3", "wpb": "2952.1", "bsz": "139.2", "num_updates": "91570", "lr": "0.000104502", "gnorm": "0.63", "train_wall": "1", "gb_free": "13.5", "wall": "64"}
# 2023-09-03 23:43:08 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-09-03 23:43:08 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:43:09 | INFO | valid | {"epoch": 422, "valid_loss": "9.49", "valid_nll_loss": "8.653", "valid_ppl": "402.65", "valid_wps": "54535.6", "valid_wpb": "2334.3", "valid_bsz": "95.2", "valid_num_updates": "91574", "valid_best_loss": "8.369"}
# 2023-09-03 23:43:09 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 422 @ 91574 updates
# 2023-09-03 23:43:09 | INFO | fairseq.trainer | Saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:43:10 | INFO | fairseq.trainer | Finished saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:43:10 | INFO | fairseq.checkpoint_utils | Saved checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt (epoch 422 @ 91574 updates, score 9.49) (writing took 1.0333750370000416 seconds)
# 2023-09-03 23:43:10 | INFO | fairseq_cli.train | end of epoch 422 (average epoch stats below)
# 2023-09-03 23:43:10 | INFO | train | {"epoch": 422, "train_loss": "2.243", "train_nll_loss": "0.372", "train_ppl": "1.29", "train_wps": "20866.4", "train_ups": "6.76", "train_wpb": "3086.4", "train_bsz": "126.9", "train_num_updates": "91574", "train_lr": "0.000104499", "train_gnorm": "0.578", "train_train_wall": "29", "train_gb_free": "13.6", "train_wall": "66"}
# 2023-09-03 23:43:10 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:43:10 | INFO | fairseq.data.iterators | grouped total_num_itrs = 217
# 2023-09-03 23:43:10 | INFO | fairseq.trainer | begin training epoch 423
# 2023-09-03 23:43:10 | INFO | fairseq_cli.train | Start iterating over samples
# 2023-09-03 23:43:10 | INFO | train_inner | {"epoch": 423, "update": 422.028, "loss": "2.257", "nll_loss": "0.376", "ppl": "1.3", "wps": "7843.6", "ups": "3.08", "wpb": "2545.4", "bsz": "123.2", "num_updates": "91580", "lr": "0.000104496", "gnorm": "0.654", "train_wall": "1", "gb_free": "14", "wall": "67"}
# 2023-09-03 23:43:12 | INFO | train_inner | {"epoch": 423, "update": 422.074, "loss": "2.211", "nll_loss": "0.342", "ppl": "1.27", "wps": "21739.4", "ups": "6.7", "wpb": "3244.9", "bsz": "127.2", "num_updates": "91590", "lr": "0.00010449", "gnorm": "0.532", "train_wall": "1", "gb_free": "13.3", "wall": "69"}
# 2023-09-03 23:43:13 | INFO | train_inner | {"epoch": 423, "update": 422.12, "loss": "2.27", "nll_loss": "0.406", "ppl": "1.32", "wps": "19799.8", "ups": "6.62", "wpb": "2990.8", "bsz": "148", "num_updates": "91600", "lr": "0.000104485", "gnorm": "0.633", "train_wall": "1", "gb_free": "13.5", "wall": "70"}
# 2023-09-03 23:43:15 | INFO | train_inner | {"epoch": 423, "update": 422.166, "loss": "2.213", "nll_loss": "0.341", "ppl": "1.27", "wps": "22756.5", "ups": "6.73", "wpb": "3382.2", "bsz": "161.6", "num_updates": "91610", "lr": "0.000104479", "gnorm": "0.587", "train_wall": "1", "gb_free": "13.4", "wall": "72"}
# 2023-09-03 23:43:16 | INFO | train_inner | {"epoch": 423, "update": 422.212, "loss": "2.178", "nll_loss": "0.319", "ppl": "1.25", "wps": "20994.3", "ups": "6.8", "wpb": "3088.5", "bsz": "136.8", "num_updates": "91620", "lr": "0.000104473", "gnorm": "0.55", "train_wall": "1", "gb_free": "13.4", "wall": "73"}
# 2023-09-03 23:43:18 | INFO | train_inner | {"epoch": 423, "update": 422.258, "loss": "2.19", "nll_loss": "0.315", "ppl": "1.24", "wps": "17116.4", "ups": "5.69", "wpb": "3009.6", "bsz": "104.8", "num_updates": "91630", "lr": "0.000104467", "gnorm": "0.496", "train_wall": "2", "gb_free": "13.5", "wall": "75"}
# 2023-09-03 23:43:20 | INFO | train_inner | {"epoch": 423, "update": 422.304, "loss": "2.226", "nll_loss": "0.352", "ppl": "1.28", "wps": "19066", "ups": "6.05", "wpb": "3150.1", "bsz": "120", "num_updates": "91640", "lr": "0.000104462", "gnorm": "0.532", "train_wall": "2", "gb_free": "13.5", "wall": "77"}
# 2023-09-03 23:43:21 | INFO | train_inner | {"epoch": 423, "update": 422.35, "loss": "2.255", "nll_loss": "0.39", "ppl": "1.31", "wps": "25275", "ups": "7.56", "wpb": "3342.7", "bsz": "136", "num_updates": "91650", "lr": "0.000104456", "gnorm": "0.562", "train_wall": "1", "gb_free": "13.4", "wall": "78"}
# 2023-09-03 23:43:22 | INFO | train_inner | {"epoch": 423, "update": 422.396, "loss": "2.225", "nll_loss": "0.36", "ppl": "1.28", "wps": "22978.5", "ups": "7.8", "wpb": "2947.7", "bsz": "129.6", "num_updates": "91660", "lr": "0.00010445", "gnorm": "0.543", "train_wall": "1", "gb_free": "13.4", "wall": "79"}
# 2023-09-03 23:43:24 | INFO | train_inner | {"epoch": 423, "update": 422.442, "loss": "2.175", "nll_loss": "0.302", "ppl": "1.23", "wps": "22056.6", "ups": "7.73", "wpb": "2854.5", "bsz": "130.4", "num_updates": "91670", "lr": "0.000104445", "gnorm": "0.488", "train_wall": "1", "gb_free": "13.5", "wall": "81"}
# 2023-09-03 23:43:25 | INFO | train_inner | {"epoch": 423, "update": 422.488, "loss": "2.188", "nll_loss": "0.313", "ppl": "1.24", "wps": "22923", "ups": "8.22", "wpb": "2789.9", "bsz": "103.2", "num_updates": "91680", "lr": "0.000104439", "gnorm": "0.528", "train_wall": "1", "gb_free": "13.5", "wall": "82"}
# 2023-09-03 23:43:26 | INFO | train_inner | {"epoch": 423, "update": 422.535, "loss": "2.14", "nll_loss": "0.279", "ppl": "1.21", "wps": "23535.3", "ups": "7.47", "wpb": "3150.9", "bsz": "152", "num_updates": "91690", "lr": "0.000104433", "gnorm": "0.5", "train_wall": "1", "gb_free": "13.4", "wall": "83"}
# 2023-09-03 23:43:28 | INFO | train_inner | {"epoch": 423, "update": 422.581, "loss": "2.235", "nll_loss": "0.366", "ppl": "1.29", "wps": "25870.3", "ups": "7.45", "wpb": "3472.7", "bsz": "124.8", "num_updates": "91700", "lr": "0.000104428", "gnorm": "0.532", "train_wall": "1", "gb_free": "13.4", "wall": "84"}
# 2023-09-03 23:43:29 | INFO | train_inner | {"epoch": 423, "update": 422.627, "loss": "2.202", "nll_loss": "0.316", "ppl": "1.24", "wps": "25447.6", "ups": "7.33", "wpb": "3471.1", "bsz": "140.8", "num_updates": "91710", "lr": "0.000104422", "gnorm": "0.499", "train_wall": "1", "gb_free": "13.5", "wall": "86"}
# 2023-09-03 23:43:30 | INFO | train_inner | {"epoch": 423, "update": 422.673, "loss": "2.245", "nll_loss": "0.363", "ppl": "1.29", "wps": "22707.7", "ups": "7.39", "wpb": "3073.6", "bsz": "112.8", "num_updates": "91720", "lr": "0.000104416", "gnorm": "0.617", "train_wall": "1", "gb_free": "13.6", "wall": "87"}
# 2023-09-03 23:43:32 | INFO | train_inner | {"epoch": 423, "update": 422.719, "loss": "2.231", "nll_loss": "0.368", "ppl": "1.29", "wps": "20899.7", "ups": "6.78", "wpb": "3083.4", "bsz": "147.2", "num_updates": "91730", "lr": "0.000104411", "gnorm": "0.522", "train_wall": "1", "gb_free": "13.6", "wall": "89"}
# 2023-09-03 23:43:33 | INFO | train_inner | {"epoch": 423, "update": 422.765, "loss": "2.243", "nll_loss": "0.377", "ppl": "1.3", "wps": "22278.9", "ups": "6.82", "wpb": "3266.9", "bsz": "122.4", "num_updates": "91740", "lr": "0.000104405", "gnorm": "0.583", "train_wall": "1", "gb_free": "13.4", "wall": "90"}
# 2023-09-03 23:43:35 | INFO | train_inner | {"epoch": 423, "update": 422.811, "loss": "2.177", "nll_loss": "0.305", "ppl": "1.24", "wps": "20338.5", "ups": "6.4", "wpb": "3180.3", "bsz": "103.2", "num_updates": "91750", "lr": "0.000104399", "gnorm": "0.508", "train_wall": "1", "gb_free": "13.5", "wall": "92"}
# 2023-09-03 23:43:36 | INFO | train_inner | {"epoch": 423, "update": 422.857, "loss": "2.462", "nll_loss": "0.614", "ppl": "1.53", "wps": "21842.7", "ups": "7.22", "wpb": "3023.4", "bsz": "116", "num_updates": "91760", "lr": "0.000104393", "gnorm": "0.633", "train_wall": "1", "gb_free": "13.6", "wall": "93"}
# 2023-09-03 23:43:38 | INFO | train_inner | {"epoch": 423, "update": 422.903, "loss": "2.277", "nll_loss": "0.395", "ppl": "1.31", "wps": "22128.5", "ups": "7.26", "wpb": "3049.1", "bsz": "114.4", "num_updates": "91770", "lr": "0.000104388", "gnorm": "0.676", "train_wall": "1", "gb_free": "13.6", "wall": "94"}
# 2023-09-03 23:43:39 | INFO | train_inner | {"epoch": 423, "update": 422.949, "loss": "2.177", "nll_loss": "0.307", "ppl": "1.24", "wps": "21529.7", "ups": "7.54", "wpb": "2853.8", "bsz": "148.8", "num_updates": "91780", "lr": "0.000104382", "gnorm": "0.565", "train_wall": "1", "gb_free": "13.4", "wall": "96"}
# 2023-09-03 23:43:40 | INFO | train_inner | {"epoch": 423, "update": 422.995, "loss": "2.342", "nll_loss": "0.461", "ppl": "1.38", "wps": "26156.1", "ups": "8.9", "wpb": "2940.2", "bsz": "99.2", "num_updates": "91790", "lr": "0.000104376", "gnorm": "0.689", "train_wall": "1", "gb_free": "13.7", "wall": "97"}
# 2023-09-03 23:43:40 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-09-03 23:43:40 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:43:41 | INFO | valid | {"epoch": 423, "valid_loss": "9.472", "valid_nll_loss": "8.634", "valid_ppl": "397.18", "valid_wps": "55338.9", "valid_wpb": "2334.3", "valid_bsz": "95.2", "valid_num_updates": "91791", "valid_best_loss": "8.369"}
# 2023-09-03 23:43:41 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 423 @ 91791 updates
# 2023-09-03 23:43:41 | INFO | fairseq.trainer | Saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:43:42 | INFO | fairseq.trainer | Finished saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-03 23:43:42 | INFO | fairseq.checkpoint_utils | Saved checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt (epoch 423 @ 91791 updates, score 9.472) (writing took 0.9488779149999118 seconds)
# 2023-09-03 23:43:42 | INFO | fairseq_cli.train | end of epoch 423 (average epoch stats below)
# 2023-09-03 23:43:42 | INFO | train | {"epoch": 423, "train_loss": "2.231", "train_nll_loss": "0.361", "train_ppl": "1.28", "train_wps": "20588.1", "train_ups": "6.67", "train_wpb": "3086.4", "train_bsz": "126.9", "train_num_updates": "91791", "train_lr": "0.000104376", "train_gnorm": "0.562", "train_train_wall": "29", "train_gb_free": "13.4", "train_wall": "99"}
# 2023-09-03 23:43:42 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-03 23:43:42 | INFO | fairseq.data.iterators | grouped total_num_itrs = 217
# 2023-09-03 23:43:42 | INFO | fairseq.trainer | begin training epoch 424
# 2023-09-03 23:43:42 | INFO | fairseq_cli.train | Start iterating over samples
# 2023-09-03 23:43:43 | INFO | train_inner | {"epoch": 424, "update": 423.041, "loss": "2.239", "nll_loss": "0.373", "ppl": "1.29", "wps": "9060.8", "ups": "3.08", "wpb": "2944.8", "bsz": "113.6", "num_updates": "91800", "lr": "0.000104371", "gnorm": "0.553", "train_wall": "1", "gb_free": "13.6", "wall": "100"}
# 2023-09-03 23:43:45 | INFO | train_inner | {"epoch": 424, "update": 423.088, "loss": "2.193", "nll_loss": "0.326", "ppl": "1.25", "wps": "25668.1", "ups": "7.67", "wpb": "3347.7", "bsz": "121.6", "num_updates": "91810", "lr": "0.000104365", "gnorm": "0.502", "train_wall": "1", "gb_free": "13.5", "wall": "102"}
# 2023-09-03 23:43:46 | INFO | train_inner | {"epoch": 424, "update": 423.134, "loss": "2.202", "nll_loss": "0.323", "ppl": "1.25", "wps": "23553.5", "ups": "7.96", "wpb": "2959.1", "bsz": "102.4", "num_updates": "91820", "lr": "0.000104359", "gnorm": "0.511", "train_wall": "1", "gb_free": "13.4", "wall": "103"}
# 2023-09-03 23:43:47 | INFO | train_inner | {"epoch": 424, "update": 423.18, "loss": "2.186", "nll_loss": "0.313", "ppl": "1.24", "wps": "24660", "ups": "7.87", "wpb": "3132.1", "bsz": "100", "num_updates": "91830", "lr": "0.000104354", "gnorm": "0.518", "train_wall": "1", "gb_free": "13.6", "wall": "104"}
# 2023-09-03 23:43:49 | INFO | train_inner | {"epoch": 424, "update": 423.226, "loss": "2.153", "nll_loss": "0.286", "ppl": "1.22", "wps": "22578.9", "ups": "7.6", "wpb": "2970.2", "bsz": "130.4", "num_updates": "91840", "lr": "0.000104348", "gnorm": "0.485", "train_wall": "1", "gb_free": "13.5", "wall": "105"}
# 2023-09-03 23:43:50 | INFO | train_inner | {"epoch": 424, "update": 423.272, "loss": "2.284", "nll_loss": "0.412", "ppl": "1.33", "wps": "19518.8", "ups": "6.79", "wpb": "2872.6", "bsz": "117.6", "num_updates": "91850", "lr": "0.000104342", "gnorm": "0.602", "train_wall": "1", "gb_free": "13.3", "wall": "107"}
# 2023-09-03 23:43:51 | INFO | train_inner | {"epoch": 424, "update": 423.318, "loss": "2.193", "nll_loss": "0.332", "ppl": "1.26", "wps": "21647.7", "ups": "6.91", "wpb": "3131.4", "bsz": "154.4", "num_updates": "91860", "lr": "0.000104337", "gnorm": "0.555", "train_wall": "1", "gb_free": "13.5", "wall": "108"}
# 2023-09-03 23:43:53 | INFO | train_inner | {"epoch": 424, "update": 423.364, "loss": "2.191", "nll_loss": "0.331", "ppl": "1.26", "wps": "17246.9", "ups": "5.84", "wpb": "2951.7", "bsz": "170.4", "num_updates": "91870", "lr": "0.000104331", "gnorm": "0.509", "train_wall": "2", "gb_free": "13.4", "wall": "110"}
# ...
# 2023-09-04 00:09:49 | INFO | train_inner | {"epoch": 472, "update": 471.843, "loss": "2.211", "nll_loss": "0.337", "ppl": "1.26", "wps": "23401.7", "ups": "7.87", "wpb": "2974", "bsz": "143.2", "num_updates": "102390", "lr": "9.8826e-05", "gnorm": "0.551", "train_wall": "1", "gb_free": "13.3", "wall": "1666"}
# 2023-09-04 00:09:51 | INFO | train_inner | {"epoch": 472, "update": 471.889, "loss": "2.208", "nll_loss": "0.341", "ppl": "1.27", "wps": "21800.7", "ups": "6.83", "wpb": "3190.6", "bsz": "111.2", "num_updates": "102400", "lr": "9.88212e-05", "gnorm": "0.535", "train_wall": "1", "gb_free": "13.3", "wall": "1667"}
# 2023-09-04 00:09:52 | INFO | train_inner | {"epoch": 472, "update": 471.935, "loss": "2.25", "nll_loss": "0.393", "ppl": "1.31", "wps": "21161.4", "ups": "6.2", "wpb": "3410.4", "bsz": "128", "num_updates": "102410", "lr": "9.88164e-05", "gnorm": "0.527", "train_wall": "2", "gb_free": "13.3", "wall": "1669"}
# 2023-09-04 00:09:53 | INFO | train_inner | {"epoch": 472, "update": 471.982, "loss": "2.281", "nll_loss": "0.425", "ppl": "1.34", "wps": "22095.9", "ups": "7.7", "wpb": "2869.9", "bsz": "138.4", "num_updates": "102420", "lr": "9.88115e-05", "gnorm": "0.545", "train_wall": "1", "gb_free": "13.7", "wall": "1670"}
# 2023-09-04 00:09:54 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-09-04 00:09:54 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-04 00:09:55 | INFO | valid | {"epoch": 472, "valid_loss": "9.494", "valid_nll_loss": "8.656", "valid_ppl": "403.3", "valid_wps": "47612.3", "valid_wpb": "2334.3", "valid_bsz": "95.2", "valid_num_updates": "102424", "valid_best_loss": "8.369"}
# 2023-09-04 00:09:55 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 472 @ 102424 updates
# 2023-09-04 00:09:55 | INFO | fairseq.trainer | Saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-04 00:09:56 | INFO | fairseq.trainer | Finished saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-04 00:09:56 | INFO | fairseq.checkpoint_utils | Saved checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt (epoch 472 @ 102424 updates, score 9.494) (writing took 1.195305049000126 seconds)
# 2023-09-04 00:09:56 | INFO | fairseq_cli.train | end of epoch 472 (average epoch stats below)
# 2023-09-04 00:09:56 | INFO | train | {"epoch": 472, "train_loss": "2.228", "train_nll_loss": "0.365", "train_ppl": "1.29", "train_wps": "20707.8", "train_ups": "6.71", "train_wpb": "3086.4", "train_bsz": "126.9", "train_num_updates": "102424", "train_lr": "9.88096e-05", "train_gnorm": "0.562", "train_train_wall": "29", "train_gb_free": "13.6", "train_wall": "1673"}
# 2023-09-04 00:09:56 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-04 00:09:56 | INFO | fairseq.data.iterators | grouped total_num_itrs = 217
# 2023-09-04 00:09:56 | INFO | fairseq.trainer | begin training epoch 473
# 2023-09-04 00:09:56 | INFO | fairseq_cli.train | Start iterating over samples
# 2023-09-04 00:09:58 | INFO | train_inner | {"epoch": 473, "update": 472.028, "loss": "2.302", "nll_loss": "0.436", "ppl": "1.35", "wps": "8204.1", "ups": "2.47", "wpb": "3325.8", "bsz": "129.6", "num_updates": "102430", "lr": "9.88067e-05", "gnorm": "0.645", "train_wall": "2", "gb_free": "13.5", "wall": "1674"}
# 2023-09-04 00:09:59 | INFO | train_inner | {"epoch": 473, "update": 472.074, "loss": "2.157", "nll_loss": "0.296", "ppl": "1.23", "wps": "22696.1", "ups": "7.37", "wpb": "3080.4", "bsz": "132", "num_updates": "102440", "lr": "9.88019e-05", "gnorm": "0.527", "train_wall": "1", "gb_free": "13.3", "wall": "1676"}
# 2023-09-04 00:10:00 | INFO | train_inner | {"epoch": 473, "update": 472.12, "loss": "2.262", "nll_loss": "0.399", "ppl": "1.32", "wps": "24133.9", "ups": "7.73", "wpb": "3123.3", "bsz": "128", "num_updates": "102450", "lr": "9.87971e-05", "gnorm": "0.574", "train_wall": "1", "gb_free": "13.6", "wall": "1677"}
# 2023-09-04 00:10:01 | INFO | train_inner | {"epoch": 473, "update": 472.166, "loss": "2.208", "nll_loss": "0.346", "ppl": "1.27", "wps": "25040.6", "ups": "7.9", "wpb": "3169.1", "bsz": "170.4", "num_updates": "102460", "lr": "9.87922e-05", "gnorm": "0.583", "train_wall": "1", "gb_free": "13.5", "wall": "1678"}
# 2023-09-04 00:10:03 | INFO | train_inner | {"epoch": 473, "update": 472.212, "loss": "2.147", "nll_loss": "0.293", "ppl": "1.23", "wps": "22966.7", "ups": "7.77", "wpb": "2954.6", "bsz": "129.6", "num_updates": "102470", "lr": "9.87874e-05", "gnorm": "0.464", "train_wall": "1", "gb_free": "13.5", "wall": "1680"}
# 2023-09-04 00:10:04 | INFO | train_inner | {"epoch": 473, "update": 472.258, "loss": "2.216", "nll_loss": "0.339", "ppl": "1.26", "wps": "20364.4", "ups": "7.09", "wpb": "2873.1", "bsz": "104", "num_updates": "102480", "lr": "9.87826e-05", "gnorm": "0.524", "train_wall": "1", "gb_free": "13.5", "wall": "1681"}
# 2023-09-04 00:10:06 | INFO | train_inner | {"epoch": 473, "update": 472.304, "loss": "2.323", "nll_loss": "0.454", "ppl": "1.37", "wps": "23384.3", "ups": "7.59", "wpb": "3079.1", "bsz": "118.4", "num_updates": "102490", "lr": "9.87778e-05", "gnorm": "0.705", "train_wall": "1", "gb_free": "13.5", "wall": "1682"}
# 2023-09-04 00:10:07 | INFO | train_inner | {"epoch": 473, "update": 472.35, "loss": "2.205", "nll_loss": "0.339", "ppl": "1.26", "wps": "26154", "ups": "7.55", "wpb": "3465.4", "bsz": "131.2", "num_updates": "102500", "lr": "9.8773e-05", "gnorm": "0.554", "train_wall": "1", "gb_free": "13.4", "wall": "1684"}
# 2023-09-04 00:10:08 | INFO | train_inner | {"epoch": 473, "update": 472.396, "loss": "2.191", "nll_loss": "0.321", "ppl": "1.25", "wps": "23108.4", "ups": "8.07", "wpb": "2863.8", "bsz": "110.4", "num_updates": "102510", "lr": "9.87681e-05", "gnorm": "0.577", "train_wall": "1", "gb_free": "13.5", "wall": "1685"}
# 2023-09-04 00:10:10 | INFO | train_inner | {"epoch": 473, "update": 472.442, "loss": "2.167", "nll_loss": "0.303", "ppl": "1.23", "wps": "21983.4", "ups": "6.74", "wpb": "3263", "bsz": "126.4", "num_updates": "102520", "lr": "9.87633e-05", "gnorm": "0.52", "train_wall": "1", "gb_free": "13.4", "wall": "1686"}
# 2023-09-04 00:10:11 | INFO | train_inner | {"epoch": 473, "update": 472.488, "loss": "2.178", "nll_loss": "0.307", "ppl": "1.24", "wps": "20973.6", "ups": "6.71", "wpb": "3126.7", "bsz": "128.8", "num_updates": "102530", "lr": "9.87585e-05", "gnorm": "0.547", "train_wall": "1", "gb_free": "13.5", "wall": "1688"}
# 2023-09-04 00:10:12 | INFO | train_inner | {"epoch": 473, "update": 472.535, "loss": "2.408", "nll_loss": "0.563", "ppl": "1.48", "wps": "22537.3", "ups": "7.16", "wpb": "3146", "bsz": "128", "num_updates": "102540", "lr": "9.87537e-05", "gnorm": "0.653", "train_wall": "1", "gb_free": "13.5", "wall": "1689"}
# 2023-09-04 00:10:14 | INFO | train_inner | {"epoch": 473, "update": 472.581, "loss": "2.243", "nll_loss": "0.38", "ppl": "1.3", "wps": "20749", "ups": "6.23", "wpb": "3330", "bsz": "104", "num_updates": "102550", "lr": "9.87489e-05", "gnorm": "0.538", "train_wall": "1", "gb_free": "13.4", "wall": "1691"}
# 2023-09-04 00:10:15 | INFO | train_inner | {"epoch": 473, "update": 472.627, "loss": "2.325", "nll_loss": "0.446", "ppl": "1.36", "wps": "20638.8", "ups": "7.02", "wpb": "2939.5", "bsz": "107.2", "num_updates": "102560", "lr": "9.87441e-05", "gnorm": "0.752", "train_wall": "1", "gb_free": "13.6", "wall": "1692"}
# 2023-09-04 00:10:17 | INFO | train_inner | {"epoch": 473, "update": 472.673, "loss": "2.237", "nll_loss": "0.378", "ppl": "1.3", "wps": "22214.1", "ups": "6.83", "wpb": "3250.4", "bsz": "124.8", "num_updates": "102570", "lr": "9.87392e-05", "gnorm": "0.553", "train_wall": "1", "gb_free": "13.5", "wall": "1694"}
# 2023-09-04 00:10:18 | INFO | train_inner | {"epoch": 473, "update": 472.719, "loss": "2.23", "nll_loss": "0.358", "ppl": "1.28", "wps": "24921.6", "ups": "7.74", "wpb": "3219.8", "bsz": "125.6", "num_updates": "102580", "lr": "9.87344e-05", "gnorm": "0.559", "train_wall": "1", "gb_free": "13.6", "wall": "1695"}
# 2023-09-04 00:10:20 | INFO | train_inner | {"epoch": 473, "update": 472.765, "loss": "2.203", "nll_loss": "0.324", "ppl": "1.25", "wps": "23993.5", "ups": "7.69", "wpb": "3121.8", "bsz": "111.2", "num_updates": "102590", "lr": "9.87296e-05", "gnorm": "0.537", "train_wall": "1", "gb_free": "13.5", "wall": "1696"}
# 2023-09-04 00:10:21 | INFO | train_inner | {"epoch": 473, "update": 472.811, "loss": "2.246", "nll_loss": "0.38", "ppl": "1.3", "wps": "25146.5", "ups": "7.63", "wpb": "3293.9", "bsz": "168", "num_updates": "102600", "lr": "9.87248e-05", "gnorm": "0.61", "train_wall": "1", "gb_free": "13.5", "wall": "1698"}
# 2023-09-04 00:10:22 | INFO | train_inner | {"epoch": 473, "update": 472.857, "loss": "2.237", "nll_loss": "0.365", "ppl": "1.29", "wps": "23857.2", "ups": "8.58", "wpb": "2779.4", "bsz": "116", "num_updates": "102610", "lr": "9.872e-05", "gnorm": "0.665", "train_wall": "1", "gb_free": "13.6", "wall": "1699"}
# 2023-09-04 00:10:23 | INFO | train_inner | {"epoch": 473, "update": 472.903, "loss": "2.231", "nll_loss": "0.353", "ppl": "1.28", "wps": "24715.8", "ups": "7.57", "wpb": "3265.2", "bsz": "128.8", "num_updates": "102620", "lr": "9.87152e-05", "gnorm": "0.519", "train_wall": "1", "gb_free": "13.4", "wall": "1700"}
# 2023-09-04 00:10:25 | INFO | train_inner | {"epoch": 473, "update": 472.949, "loss": "2.113", "nll_loss": "0.264", "ppl": "1.2", "wps": "20527.3", "ups": "8", "wpb": "2565.4", "bsz": "140", "num_updates": "102630", "lr": "9.87104e-05", "gnorm": "0.453", "train_wall": "1", "gb_free": "13.5", "wall": "1701"}
# 2023-09-04 00:10:26 | INFO | train_inner | {"epoch": 473, "update": 472.995, "loss": "2.186", "nll_loss": "0.332", "ppl": "1.26", "wps": "24235", "ups": "8.32", "wpb": "2912.3", "bsz": "112.8", "num_updates": "102640", "lr": "9.87056e-05", "gnorm": "0.57", "train_wall": "1", "gb_free": "13.5", "wall": "1703"}
# 2023-09-04 00:10:26 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-09-04 00:10:26 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-04 00:10:27 | INFO | valid | {"epoch": 473, "valid_loss": "9.5", "valid_nll_loss": "8.667", "valid_ppl": "406.47", "valid_wps": "52596.3", "valid_wpb": "2334.3", "valid_bsz": "95.2", "valid_num_updates": "102641", "valid_best_loss": "8.369"}
# 2023-09-04 00:10:27 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 473 @ 102641 updates
# 2023-09-04 00:10:27 | INFO | fairseq.trainer | Saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-04 00:10:29 | INFO | fairseq.trainer | Finished saving checkpoint to /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# 2023-09-04 00:10:29 | INFO | fairseq.checkpoint_utils | Saved checkpoint /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt (epoch 473 @ 102641 updates, score 9.5) (writing took 1.596866011000202 seconds)
# 2023-09-04 00:10:29 | INFO | fairseq_cli.train | end of epoch 473 (average epoch stats below)
# 2023-09-04 00:10:29 | INFO | train | {"epoch": 473, "train_loss": "2.223", "train_nll_loss": "0.358", "train_ppl": "1.28", "train_wps": "20783.3", "train_ups": "6.73", "train_wpb": "3086.4", "train_bsz": "126.9", "train_num_updates": "102641", "train_lr": "9.87051e-05", "train_gnorm": "0.569", "train_train_wall": "28", "train_gb_free": "13.5", "train_wall": "1705"}
# 2023-09-04 00:10:29 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-09-04 00:10:29 | INFO | fairseq.data.iterators | grouped total_num_itrs = 217
# 2023-09-04 00:10:29 | INFO | fairseq.trainer | begin training epoch 474
# 2023-09-04 00:10:29 | INFO | fairseq_cli.train | Start iterating over samples
# 2023-09-04 00:10:30 | INFO | train_inner | {"epoch": 474, "update": 473.041, "loss": "2.191", "nll_loss": "0.326", "ppl": "1.25", "wps": "6978.3", "ups": "2.29", "wpb": "3052", "bsz": "115.2", "num_updates": "102650", "lr": "9.87008e-05", "gnorm": "0.56", "train_wall": "2", "gb_free": "13.5", "wall": "1707"}
# 2023-09-04 00:10:32 | INFO | train_inner | {"epoch": 474, "update": 473.088, "loss": "2.225", "nll_loss": "0.352", "ppl": "1.28", "wps": "19899.5", "ups": "6.77", "wpb": "2940.9", "bsz": "100", "num_updates": "102660", "lr": "9.8696e-05", "gnorm": "0.571", "train_wall": "1", "gb_free": "13.4", "wall": "1708"}
# 2023-09-04 00:10:33 | INFO | train_inner | {"epoch": 474, "update": 473.134, "loss": "2.197", "nll_loss": "0.336", "ppl": "1.26", "wps": "21209.5", "ups": "6.69", "wpb": "3169.1", "bsz": "111.2", "num_updates": "102670", "lr": "9.86912e-05", "gnorm": "0.526", "train_wall": "1", "gb_free": "13.4", "wall": "1710"}
# 2023-09-04 00:10:35 | INFO | train_inner | {"epoch": 474, "update": 473.18, "loss": "2.23", "nll_loss": "0.357", "ppl": "1.28", "wps": "18728.5", "ups": "6.74", "wpb": "2778.1", "bsz": "102.4", "num_updates": "102680", "lr": "9.86863e-05", "gnorm": "0.609", "train_wall": "1", "gb_free": "13.5", "wall": "1711"}
# 2023-09-04 00:10:36 | INFO | train_inner | {"epoch": 474, "update": 473.226, "loss": "2.21", "nll_loss": "0.336", "ppl": "1.26", "wps": "23455", "ups": "7.52", "wpb": "3119.9", "bsz": "88.8", "num_updates": "102690", "lr": "9.86815e-05", "gnorm": "0.542", "train_wall": "1", "gb_free": "13.5", "wall": "1713"}
# 2023-09-04 00:10:37 | INFO | train_inner | {"epoch": 474, "update": 473.272, "loss": "2.204", "nll_loss": "0.324", "ppl": "1.25", "wps": "20195", "ups": "7.22", "wpb": "2798.2", "bsz": "118.4", "num_updates": "102700", "lr": "9.86767e-05", "gnorm": "0.57", "train_wall": "1", "gb_free": "13.5", "wall": "1714"}
# 2023-09-04 00:10:39 | INFO | train_inner | {"epoch": 474, "update": 473.318, "loss": "2.323", "nll_loss": "0.458", "ppl": "1.37", "wps": "21603.7", "ups": "6.88", "wpb": "3138.1", "bsz": "138.4", "num_updates": "102710", "lr": "9.86719e-05", "gnorm": "0.596", "train_wall": "1", "gb_free": "13.4", "wall": "1716"}
# 2023-09-04 00:10:40 | INFO | train_inner | {"epoch": 474, "update": 473.364, "loss": "2.221", "nll_loss": "0.345", "ppl": "1.27", "wps": "24045.2", "ups": "8.04", "wpb": "2989", "bsz": "138.4", "num_updates": "102720", "lr": "9.86671e-05", "gnorm": "0.558", "train_wall": "1", "gb_free": "13.4", "wall": "1717"}
# 2023-09-04 00:10:41 | INFO | train_inner | {"epoch": 474, "update": 473.41, "loss": "2.29", "nll_loss": "0.433", "ppl": "1.35", "wps": "24259.5", "ups": "8.12", "wpb": "2986", "bsz": "104", "num_updates": "102730", "lr": "9.86623e-05", "gnorm": "0.67", "train_wall": "1", "gb_free": "13.4", "wall": "1718"}
# 2023-09-04 00:10:43 | INFO | train_inner | {"epoch": 474, "update": 473.456, "loss": "2.14", "nll_loss": "0.283", "ppl": "1.22", "wps": "21760.5", "ups": "7.62", "wpb": "2854.1", "bsz": "144", "num_updates": "102740", "lr": "9.86575e-05", "gnorm": "0.476", "train_wall": "1", "gb_free": "13.4", "wall": "1719"}
# 2023-09-04 00:10:44 | INFO | train_inner | {"epoch": 474, "update": 473.502, "loss": "2.194", "nll_loss": "0.326", "ppl": "1.25", "wps": "26480.7", "ups": "7.33", "wpb": "3612.4", "bsz": "165.6", "num_updates": "102750", "lr": "9.86527e-05", "gnorm": "0.512", "train_wall": "1", "gb_free": "13.5", "wall": "1721"}
# 2023-09-04 00:10:45 | INFO | train_inner | {"epoch": 474, "update": 473.548, "loss": "2.278", "nll_loss": "0.399", "ppl": "1.32", "wps": "19371.1", "ups": "7.84", "wpb": "2471.6", "bsz": "108", "num_updates": "102760", "lr": "9.86479e-05", "gnorm": "0.631", "train_wall": "1", "gb_free": "13.5", "wall": "1722"}
# 2023-09-04 00:10:47 | INFO | train_inner | {"epoch": 474, "update": 473.594, "loss": "2.248", "nll_loss": "0.377", "ppl": "1.3", "wps": "22808.9", "ups": "6.72", "wpb": "3395.6", "bsz": "135.2", "num_updates": "102770", "lr": "9.86431e-05", "gnorm": "0.58", "train_wall": "1", "gb_free": "13.5", "wall": "1724"}
# ^C

# %%
# https://wandb.ai/arabic-swahili/LARGE_SCALE_AR_TO_SWAHILI_Translation/runs/4kb2fug4

# %%
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch==1.12.1+cu113 in /usr/local/lib/python3.10/dist-packages (1.12.1+cu113)
# Requirement already satisfied: torchvision==0.13.1+cu113 in /usr/local/lib/python3.10/dist-packages (0.13.1+cu113)
# Requirement already satisfied: torchaudio==0.12.1 in /usr/local/lib/python3.10/dist-packages (0.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.12.1+cu113) (4.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1+cu113) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1+cu113) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1+cu113) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (2023.7.22)

# %%
BATCH_SIZE = 128
BEAM=5
SEED=1
SCORING="bleu"
CHECKPOINT_PATH= f"{SAVE_DIR}checkpoint_last.pt"

# !fairseq-generate "/content/sw_ar.tokenized.sw-ar"\
    --batch-size $BATCH_SIZE \
    --beam $BEAM \
    --path $CHECKPOINT_PATH \
    --remove-bpe 'sentencepiece' \
    --seed $SEED \
    --scoring bleu > "/content/drive/MyDrive/sept3/checkpoints/latest_result.txt"
# Out:
# INFO:fairseq.tasks.text_to_speech:Please install tensorboardX: pip install tensorboardX
# DEBUG:hydra.core.utils:Setting JobRuntime:name=UNKNOWN_NAME
# DEBUG:hydra.core.utils:Setting JobRuntime:name=utils
# INFO:fairseq_cli.generate:{'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': '/content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt', 'post_process': 'sentencepiece', 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 128, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 128, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count ...
# INFO:fairseq.tasks.translation:[sw] dictionary: 12001 types
# INFO:fairseq.tasks.translation:[ar] dictionary: 12001 types
# INFO:fairseq_cli.generate:loading model(s) from /content/drive/MyDrive/sept3/checkpoints/checkpoint_last.pt
# INFO:fairseq.data.data_utils:loaded 3,281 examples from: /content/sw_ar.tokenized.sw-ar/test.sw-ar.sw
# INFO:fairseq.data.data_utils:loaded 3,281 examples from: /content/sw_ar.tokenized.sw-ar/test.sw-ar.ar
# INFO:fairseq.tasks.translation:/content/sw_ar.tokenized.sw-ar test sw-ar 3281 examples
# INFO:fairseq.tasks.fairseq_task:can_reuse_epoch_itr = True
# INFO:fairseq.tasks.fairseq_task:reuse_dataloader = True
# INFO:fairseq.tasks.fairseq_task:rebuild_batches = False
# INFO:fairseq.tasks.fairseq_task:creating new batches for epoch 1
#  38% 10/26 [00:11<00:15,  1.04it/s, wps=1678]

# %%
with open( "/content/drive/MyDrive/sept3/checkpoints/latest_result.txt" ) as f:
  text = f.read()
  text = text.split()
  print(" ".join(text[-8:-5]))
